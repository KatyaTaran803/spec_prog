# %%
import pandas as pd
import numpy as np
df = pd.read_csv('household2.txt', delimiter=';')
df.head(20)
# Out:
# c:\users\катя\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0   16/12/2006  17:24:00               4.216                 0.418  234.840
# 1   16/12/2006  17:25:00               5.360                 0.436  233.630
# 2   16/12/2006  17:26:00               5.374                 0.498  233.290
# 3   16/12/2006  17:27:00               5.388                 0.502  233.740
# 4   16/12/2006  17:28:00               3.666                 0.528  235.680
# 5   16/12/2006  17:29:00               3.520                 0.522  235.020
# 6   16/12/2006  17:30:00               3.702                 0.520  235.090
# 7   16/12/2006  17:31:00               3.700                 0.520  235.220
# ...

# %%
df=df[df['Global_active_power']!="?"]

non_float_columns = ['Date', 'Time'] 
for column in df.columns:
    if column not in non_float_columns:
        df[column]=df[column].astype(float)

# %%
df = df.reset_index(drop=True)
start = df[df['Date']=='17/6/2008'].index[0]
finish = df[df['Date']=='20/6/2008'].index[0]
df0 = df[start:finish]

df0
# Out:
#              Date      Time  Global_active_power  Global_reactive_power  \
# 785573  17/6/2008  00:00:00                0.292                  0.188
# 785574  17/6/2008  00:01:00                0.340                  0.262
# 785575  17/6/2008  00:02:00                0.336                  0.262
# 785576  17/6/2008  00:03:00                0.332                  0.264
# 785577  17/6/2008  00:04:00                0.330                  0.262
# ...           ...       ...                  ...                    ...
# 789888  19/6/2008  23:55:00                0.146                  0.000
# 789889  19/6/2008  23:56:00                0.146                  0.000
# 789890  19/6/2008  23:57:00                0.146                  0.000
# 789891  19/6/2008  23:58:00                0.146                  0.000
# 789892  19/6/2008  23:59:00                0.146                  0.000
#
#         Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
df0.groupby('Date')['Sub_metering_1'].mean().idxmax()
# Out:
# '18/6/2008'

# %%
df[df['Date']=='17/12/2006']['Sub_metering_1'].mean()
# Out:
# 1.4118055555555555
